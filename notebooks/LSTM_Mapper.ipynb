# %% [markdown]
# # LSTM Mapper

# %%
import os

os.environ["CUDA_VISIBLE_DEVICES"] = "3,4"

import numpy as np
import matplotlib.pyplot as plt
from vae_model import vae_model
import tensorflow as tf
from sklearn.model_selection import train_test_split
from tensorflow.keras.layers import (
    Input,
    Dense,
    Conv2D,
    Flatten,
    TimeDistributed,
    Reshape,
    Activation,
    LSTM,
)
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from pyeit import mesh
import random
from glob import glob
from util import (
    ensure_dir,
    load_data,
    calculate_perm_error,
    create_mesh,
    mesh_plot_comparisons,
    select_random_instances,
    plot_boxplot,
    seq_data,
    plot_mesh_permarray,
)

# Creating a mesh
mesh_obj = create_mesh()
# Out:
# 2024-12-17 09:39:27.436937: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-12-17 09:39:28.192159: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-17 09:39:39.383882: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1928] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 79087 MB memory:  -> device: 0, name: NVIDIA A100-SXM4-80GB, pci bus id: 0000:4c:00.0, compute capability: 8.0
# 2024-12-17 09:39:39.385705: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1928] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 79087 MB memory:  -> device: 1, name: NVIDIA A100-SXM4-80GB, pci bus id: 0000:84:00.0, compute capability: 8.0

# %% [markdown]
# **Load data**

# %%
data_set = 4  # select dataset
iteration = 1
# good:1,3,4,7
# bad: 2,5,6
EIT, perm_array, D, T = load_data(data_set)

perm_array = perm_array / 15
# reshape data
EIT = EIT.reshape(-1, 32, 32, 1)
perm_array = perm_array.reshape(-1, 2840, 1)
# Out:
# Time of
# 	first: 2024.10.22. 07:55:16.121000
# 	last: 2024.10.22. 08:04:39.642000
# measurement.
# Shape of EIT data: (20776, 32, 32)
# Shape of Permittivity Data: (20776, 2840)

# %% [markdown]
# **Create sequenced data**

# %%
EIT_seq, perm_array_seq = seq_data(EIT, perm_array, n_seg=4)
# EIT_seq = EIT_seq.reshape(EIT_seq.shape[0], 4, 1024, 1)
print("New Shape of Voltages Data:")
print(EIT_seq.shape)
print("New Shape of Permittivity Data:")
print(perm_array_seq.shape)
# Out:
# New Shape of Voltages Data:
# (20772, 4, 32, 32, 1)
# New Shape of Permittivity Data:
# (20772, 2840, 1)

# %% [markdown]
# **Initialization of pretrained VAE**

# %%
weights_dir = "weights"
ensure_dir(weights_dir)

# %%
vae = vae_model()
vae.compile(optimizer=tf.keras.optimizers.Adam())

# %%
vae_weights_file = os.path.join(weights_dir, "vae_2.weights.h5")

# Load the weights if they exist
if os.path.exists(vae_weights_file):
    vae.load_weights(vae_weights_file)
    print("VAE weights loaded from file.")
else:
    raise FileNotFoundError(
        "No trained VAE model found. Please train the VAE model first."
    )
# Out:
# VAE weights loaded from file.
# /home/jt292/miniconda3/envs/TF/lib/python3.10/site-packages/keras/src/saving/saving_lib.py:415: UserWarning: Skipping variable loading for optimizer 'adam', because it has 2 variables whereas the saved optimizer has 146 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))

# %%
_, _, latent_rep = vae.encoder.predict(perm_array_seq)
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1734424874.769492   31197 service.cc:145] XLA service 0x7b9638004940 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1734424874.769539   31197 service.cc:153]   StreamExecutor device (0): NVIDIA A100-SXM4-80GB, Compute Capability 8.0
# I0000 00:00:1734424874.769545   31197 service.cc:153]   StreamExecutor device (1): NVIDIA A100-SXM4-80GB, Compute Capability 8.0
# 2024-12-17 09:41:14.800255: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2024-12-17 09:41:16.667315: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:465] Loaded cuDNN version 8907
#  77/650 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# I0000 00:00:1734424877.584239   31197 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 650/650 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step

# %%
(
    x_train_seq,
    x_test_seq,
    y_train_seq,
    y_test_seq,
    z_train_seq,
    z_test_seq,
) = train_test_split(
    EIT_seq,
    perm_array_seq,
    latent_rep,
    test_size=0.1,
    shuffle=True,
    random_state=42,
)

# %% [markdown]
# **LSTM Mapper**

# %%
def mapper_model(input_shape=(4, 32, 32, 1), output_shape=8):
    mapper_inputs = Input(shape=input_shape)

    x = TimeDistributed(
        Conv2D(2, strides=(2, 2), kernel_size=(3, 3), activation="elu")
    )(mapper_inputs)
    x = TimeDistributed(
        Conv2D(2, strides=(2, 2), kernel_size=(3, 3), activation="elu")
    )(x)
    x = TimeDistributed(Flatten())(x)

    x = TimeDistributed(Dense(64, activation="elu"))(x)

    x = LSTM(32, return_sequences=True)(x)
    x = LSTM(16, return_sequences=False)(x)

    mapper_output = Dense(output_shape)(x)
    model = Model(mapper_inputs, mapper_output, name="lstm_mapper")
    return model


lstm_mapper = mapper_model()
lstm_mapper.compile(optimizer="adam", loss="mse")
lstm_mapper.summary()
# Out:
# Model: "lstm_mapper"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_6 (InputLayer)      │ (None, 4, 32, 32, 1)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_8              │ (None, 4, 15, 15, 2)   │            20 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_9              │ (None, 4, 7, 7, 2)     │            38 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_10             │ (None, 4, 98)          │             0 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_11             │ (None, 4, 64)          │         6,336 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_4 (LSTM)                   │ (None, 4, 32)          │        12,416 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_5 (LSTM)                   │ (None, 16)             │         3,136 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 8)              │           136 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 22,082 (86.26 KB)
#  Trainable params: 22,082 (86.26 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# **LSTM Mapper training**

# %%
lstm_mapper_weights_file = os.path.join(
    weights_dir, f"{data_set}_lstm_it_{iteration}.mapper.exp.weights.h5"
)

# Train or load the mapper
if os.path.exists(lstm_mapper_weights_file):
    lstm_mapper.load_weights(lstm_mapper_weights_file)
    print("Mapper LSTM weights loaded from file.")
else:
    history = lstm_mapper.fit(
        x_train_seq, z_train_seq, epochs=200, batch_size=8, validation_split=0.1
    )
    lstm_mapper.save_weights(lstm_mapper_weights_file)
    print("Mapper LSTM weights saved to file.")

    # Plot training history
    plt.figure(figsize=(6, 4))
    plt.plot(history.history["loss"], label="Training Loss")
    plt.plot(history.history["val_loss"], label="Validation Loss")
    plt.xlabel("Epochs")
    plt.ylabel("Loss")
    plt.legend()
    plt.title("Training and Validation Loss")
    plt.show()
# Out:
# Epoch 1/200
# 2103/2103 ━━━━━━━━━━━━━━━━━━━━ 21s 9ms/step - loss: 0.9367 - val_loss: 0.9364
# Epoch 2/200
# 2103/2103 ━━━━━━━━━━━━━━━━━━━━ 20s 9ms/step - loss: 0.9287 - val_loss: 0.9366
# Epoch 3/200
# 2103/2103 ━━━━━━━━━━━━━━━━━━━━ 20s 9ms/step - loss: 0.9332 - val_loss: 0.9355
# Epoch 4/200
# 2103/2103 ━━━━━━━━━━━━━━━━━━━━ 20s 9ms/step - loss: 0.9251 - val_loss: 0.9356
# Epoch 5/200
# 2103/2103 ━━━━━━━━━━━━━━━━━━━━ 20s 9ms/step - loss: 0.9276 - val_loss: 0.9356
# Epoch 6/200
# 2103/2103 ━━━━━━━━━━━━━━━━━━━━ 18s 8ms/step - loss: 0.9285 - val_loss: 0.9368
# Epoch 7/200
# 2103/2103 ━━━━━━━━━━━━━━━━━━━━ 18s 8ms/step - loss: 0.9287 - val_loss: 0.9366
# Epoch 8/200
# 2103/2103 ━━━━━━━━━━━━━━━━━━━━ 18s 8ms/step - loss: 0.9255 - val_loss: 0.9356
# Epoch 9/200
# 2103/2103 ━━━━━━━━━━━━━━━━━━━━ 18s 8ms/step - loss: 0.9221 - val_loss: 0.9363
# Epoch 10/200
# 2103/2103 ━━━━━━━━━━━━━━━━━━━━ 18s 9ms/step - loss: 0.9248 - val_loss: 0.9366
# Epoch 11/200
# 2103/2103 ━━━━━━━━━━━━━━━━━━━━ 19s 9ms/step - loss: 0.9232 - val_loss: 0.9353
# Epoch 12/200
# 2103/2103 ━━━━━━━━━━━━━━━━━━━━ 15s 7ms/step - loss: 0.9253 - val_loss: 0.9356
# Epoch 13/200
# 2103/2103 ━━━━━━━━━━━━━━━━━━━━ 18s 8ms/step - loss: 0.9275 - val_loss: 0.9366
# Epoch 14/200
# 2103/2103 ━━━━━━━━━━━━━━━━━━━━ 18s 8ms/step - loss: 0.9268 - val_loss: 0.9362
# Epoch 15/200
# 2103/2103 ━━━━━━━━━━━━━━━━━━━━ 18s 8ms/step - loss: 0.9280 - val_loss: 0.9353
# Epoch 16/200
# 2103/2103 ━━━━━━━━━━━━━━━━━━━━ 16s 8ms/step - loss: 0.9258 - val_loss: 0.9357
# Epoch 17/200
# 2103/2103 ━━━━━━━━━━━━━━━━━━━━ 19s 9ms/step - loss: 0.9308 - val_loss: 0.9355
# Epoch 18/200
# 2103/2103 ━━━━━━━━━━━━━━━━━━━━ 18s 9ms/step - loss: 0.9335 - val_loss: 0.9363
# Epoch 19/200
# 2103/2103 ━━━━━━━━━━━━━━━━━━━━ 19s 9ms/step - loss: 0.9270 - val_loss: 0.9360
# Epoch 20/200
# 2103/2103 ━━━━━━━━━━━━━━━━━━━━ 18s 8ms/step - loss: 0.9310 - val_loss: 0.9355
# Epoch 21/200
# 2103/2103 ━━━━━━━━━━━━━━━━━━━━ 17s 8ms/step - loss: 0.9255 - val_loss: 0.9359
# Epoch 22/200
# 2103/2103 ━━━━━━━━━━━━━━━━━━━━ 18s 8ms/step - loss: 0.9215 - val_loss: 0.7577
# Epoch 23/200
# 2103/2103 ━━━━━━━━━━━━━━━━━━━━ 18s 8ms/step - loss: 0.7554 - val_loss: 0.7189
# Epoch 24/200
# 2103/2103 ━━━━━━━━━━━━━━━━━━━━ 18s 8ms/step - loss: 0.7112 - val_loss: 0.6964
# Epoch 25/200
# 2103/2103 ━━━━━━━━━━━━━━━━━━━━ 18s 8ms/step - loss: 0.7017 - val_loss: 0.6818
# Epoch 26/200
# 2103/2103 ━━━━━━━━━━━━━━━━━━━━ 16s 7ms/step - loss: 0.6996 - val_loss: 0.6812
# Epoch 27/200
# 2103/2103 ━━━━━━━━━━━━━━━━━━━━ 17s 8ms/step - loss: 0.6872 - val_loss: 0.6784
# Epoch 28/200
# 2103/2103 ━━━━━━━━━━━━━━━━━━━━ 18s 8ms/step - loss: 0.6935 - val_loss: 0.6949
# Epoch 29/200
# 2103/2103 ━━━━━━━━━━━━━━━━━━━━ 16s 7ms/step - loss: 0.6934 - val_loss: 0.7067
# Epoch 30/200
# 2103/2103 ━━━━━━━━━━━━━━━━━━━━ 16s 8ms/step - loss: 0.6946 - val_loss: 0.6741
# Epoch 31/200
# 2103/2103 ━━━━━━━━━━━━━━━━━━━━ 19s 9ms/step - loss: 0.6804 - val_loss: 0.7148
# Epoch 32/200
# 2103/2103 ━━━━━━━━━━━━━━━━━━━━ 20s 9ms/step - loss: 0.6825 - val_loss: 0.6729
# Epoch 33/200
# 2103/2103 ━━━━━━━━━━━━━━━━━━━━ 18s 8ms/step - loss: 0.6878 - val_loss: 0.6721
# Epoch 34/200
# 2103/2103 ━━━━━━━━━━━━━━━━━━━━ 18s 8ms/step - loss: 0.6838 - val_loss: 0.7039
# Epoch 35/200
# 2103/2103 ━━━━━━━━━━━━━━━━━━━━ 18s 9ms/step - loss: 0.6837 - val_loss: 0.6718
# Epoch 36/200
# 2103/2103 ━━━━━━━━━━━━━━━━━━━━ 19s 9ms/step - loss: 0.6798 - val_loss: 0.6804
# Epoch 37/200
# 2103/2103 ━━━━━━━━━━━━━━━━━━━━ 16s 8ms/step - loss: 0.6798 - val_loss: 0.6737
# Epoch 38/200
# 2103/2103 ━━━━━━━━━━━━━━━━━━━━ 19s 9ms/step - loss: 0.6778 - val_loss: 0.7216
# Epoch 39/200
# 2103/2103 ━━━━━━━━━━━━━━━━━━━━ 19s 9ms/step - loss: 0.6762 - val_loss: 0.7343
# Epoch 40/200
# 2103/2103 ━━━━━━━━━━━━━━━━━━━━ 17s 8ms/step - loss: 0.6814 - val_loss: 0.7270
# Epoch 41/200
# 2103/2103 ━━━━━━━━━━━━━━━━━━━━ 16s 7ms/step - loss: 0.6718 - val_loss: 0.6843
# Epoch 42/200
# 2103/2103 ━━━━━━━━━━━━━━━━━━━━ 16s 7ms/step - loss: 0.6791 - val_loss: 0.6681
# Epoch 43/200
# 2103/2103 ━━━━━━━━━━━━━━━━━━━━ 15s 7ms/step - loss: 0.6732 - val_loss: 0.7056
# Epoch 44/200
# 2103/2103 ━━━━━━━━━━━━━━━━━━━━ 15s 7ms/step - loss: 0.6736 - val_loss: 0.6829
# Epoch 45/200
# 2103/2103 ━━━━━━━━━━━━━━━━━━━━ 18s 8ms/step - loss: 0.6713 - val_loss: 0.6924
# Epoch 46/200
# 2103/2103 ━━━━━━━━━━━━━━━━━━━━ 15s 7ms/step - loss: 0.6718 - val_loss: 0.6712
# Epoch 47/200
# 2103/2103 ━━━━━━━━━━━━━━━━━━━━ 13s 6ms/step - loss: 0.6723 - val_loss: 0.6799
# Epoch 48/200
# 2103/2103 ━━━━━━━━━━━━━━━━━━━━ 16s 7ms/step - loss: 0.6692 - val_loss: 0.7274
# Epoch 49/200
# 2103/2103 ━━━━━━━━━━━━━━━━━━━━ 15s 7ms/step - loss: 0.6755 - val_loss: 0.6712
# Epoch 50/200
# 2103/2103 ━━━━━━━━━━━━━━━━━━━━ 17s 8ms/step - loss: 0.6684 - val_loss: 0.6679
# Epoch 51/200
# 2103/2103 ━━━━━━━━━━━━━━━━━━━━ 15s 7ms/step - loss: 0.6656 - val_loss: 0.6878
# Epoch 52/200
# 2103/2103 ━━━━━━━━━━━━━━━━━━━━ 16s 8ms/step - loss: 0.6696 - val_loss: 0.6688
# Epoch 53/200
# 2103/2103 ━━━━━━━━━━━━━━━━━━━━ 18s 8ms/step - loss: 0.6730 - val_loss: 0.6798
# Epoch 54/200
# 2103/2103 ━━━━━━━━━━━━━━━━━━━━ 18s 8ms/step - loss: 0.6690 - val_loss: 0.6667
# Epoch 55/200
# 2103/2103 ━━━━━━━━━━━━━━━━━━━━ 19s 9ms/step - loss: 0.6671 - val_loss: 0.6667
# Epoch 56/200
# 2103/2103 ━━━━━━━━━━━━━━━━━━━━ 15s 7ms/step - loss: 0.6590 - val_loss: 0.6669
# Epoch 57/200
# 2103/2103 ━━━━━━━━━━━━━━━━━━━━ 17s 8ms/step - loss: 0.6728 - val_loss: 0.6660
# Epoch 58/200
# 2103/2103 ━━━━━━━━━━━━━━━━━━━━ 18s 8ms/step - loss: 0.6676 - val_loss: 0.6764
# Epoch 59/200
# 2103/2103 ━━━━━━━━━━━━━━━━━━━━ 15s 7ms/step - loss: 0.6714 - val_loss: 0.6741
# Epoch 60/200
# 2103/2103 ━━━━━━━━━━━━━━━━━━━━ 12s 6ms/step - loss: 0.6686 - val_loss: 0.6675
# Epoch 61/200
# 2103/2103 ━━━━━━━━━━━━━━━━━━━━ 14s 6ms/step - loss: 0.6674 - val_loss: 0.6659
# Epoch 62/200
# 2103/2103 ━━━━━━━━━━━━━━━━━━━━ 13s 6ms/step - loss: 0.6697 - val_loss: 0.6716
# Epoch 63/200
# 2103/2103 ━━━━━━━━━━━━━━━━━━━━ 13s 6ms/step - loss: 0.6643 - val_loss: 0.6975
# Epoch 64/200
# 2103/2103 ━━━━━━━━━━━━━━━━━━━━ 13s 6ms/step - loss: 0.6664 - val_loss: 0.7055
# Epoch 65/200
# 2103/2103 ━━━━━━━━━━━━━━━━━━━━ 13s 6ms/step - loss: 0.6684 - val_loss: 0.6678
# Epoch 66/200
# 2103/2103 ━━━━━━━━━━━━━━━━━━━━ 13s 6ms/step - loss: 0.6636 - val_loss: 0.6816
# Epoch 67/200
# 2103/2103 ━━━━━━━━━━━━━━━━━━━━ 13s 6ms/step - loss: 0.6695 - val_loss: 0.6669
# Epoch 68/200
# 2103/2103 ━━━━━━━━━━━━━━━━━━━━ 13s 6ms/step - loss: 0.6629 - val_loss: 0.6678
# Epoch 69/200
# 2103/2103 ━━━━━━━━━━━━━━━━━━━━ 17s 8ms/step - loss: 0.6649 - val_loss: 0.6663
# Epoch 70/200
# 2103/2103 ━━━━━━━━━━━━━━━━━━━━ 15s 7ms/step - loss: 0.6700 - val_loss: 0.6956
# Epoch 71/200
# 2103/2103 ━━━━━━━━━━━━━━━━━━━━ 13s 6ms/step - loss: 0.6622 - val_loss: 0.6682
# Epoch 72/200
# 2103/2103 ━━━━━━━━━━━━━━━━━━━━ 16s 7ms/step - loss: 0.6631 - val_loss: 0.6992
# Epoch 73/200
# 2103/2103 ━━━━━━━━━━━━━━━━━━━━ 15s 7ms/step - loss: 0.6688 - val_loss: 0.7224
# Epoch 74/200
# 2103/2103 ━━━━━━━━━━━━━━━━━━━━ 14s 6ms/step - loss: 0.6624 - val_loss: 0.6647
# Epoch 75/200
# 2103/2103 ━━━━━━━━━━━━━━━━━━━━ 13s 6ms/step - loss: 0.6663 - val_loss: 0.6703
# Epoch 76/200
# 2103/2103 ━━━━━━━━━━━━━━━━━━━━ 13s 6ms/step - loss: 0.6615 - val_loss: 0.6649
# Epoch 77/200
# 2103/2103 ━━━━━━━━━━━━━━━━━━━━ 15s 6ms/step - loss: 0.6712 - val_loss: 0.6674
# Epoch 78/200
# 2103/2103 ━━━━━━━━━━━━━━━━━━━━ 15s 7ms/step - loss: 0.6679 - val_loss: 0.6778
# Epoch 79/200
# 2103/2103 ━━━━━━━━━━━━━━━━━━━━ 14s 7ms/step - loss: 0.6645 - val_loss: 0.6854
# Epoch 80/200
# 2103/2103 ━━━━━━━━━━━━━━━━━━━━ 15s 7ms/step - loss: 0.6629 - val_loss: 0.6784
# Epoch 81/200
# 2103/2103 ━━━━━━━━━━━━━━━━━━━━ 14s 7ms/step - loss: 0.6615 - val_loss: 0.6687
# Epoch 82/200
# 2103/2103 ━━━━━━━━━━━━━━━━━━━━ 15s 7ms/step - loss: 0.6633 - val_loss: 0.6702
# Epoch 83/200
# 2103/2103 ━━━━━━━━━━━━━━━━━━━━ 15s 7ms/step - loss: 0.6611 - val_loss: 0.6659
# Epoch 84/200
# 2103/2103 ━━━━━━━━━━━━━━━━━━━━ 18s 9ms/step - loss: 0.6613 - val_loss: 0.6698
# Epoch 85/200
# 2103/2103 ━━━━━━━━━━━━━━━━━━━━ 19s 9ms/step - loss: 0.6629 - val_loss: 0.6649
# Epoch 86/200
# 2103/2103 ━━━━━━━━━━━━━━━━━━━━ 17s 8ms/step - loss: 0.6592 - val_loss: 0.6804
# Epoch 87/200
# 2103/2103 ━━━━━━━━━━━━━━━━━━━━ 19s 9ms/step - loss: 0.6620 - val_loss: 0.6634
# Epoch 88/200
# 2103/2103 ━━━━━━━━━━━━━━━━━━━━ 18s 8ms/step - loss: 0.6628 - val_loss: 0.6652
# Epoch 89/200
# 2103/2103 ━━━━━━━━━━━━━━━━━━━━ 20s 9ms/step - loss: 0.6609 - val_loss: 0.6653
# Epoch 90/200
# 2103/2103 ━━━━━━━━━━━━━━━━━━━━ 17s 8ms/step - loss: 0.6625 - val_loss: 0.6725
# Epoch 91/200
# 2103/2103 ━━━━━━━━━━━━━━━━━━━━ 18s 8ms/step - loss: 0.6611 - val_loss: 0.6627
# Epoch 92/200
# 2103/2103 ━━━━━━━━━━━━━━━━━━━━ 18s 8ms/step - loss: 0.6628 - val_loss: 0.6618
# Epoch 93/200
# 2103/2103 ━━━━━━━━━━━━━━━━━━━━ 17s 8ms/step - loss: 0.6594 - val_loss: 0.6818
# Epoch 94/200
# 2103/2103 ━━━━━━━━━━━━━━━━━━━━ 15s 7ms/step - loss: 0.6601 - val_loss: 0.6674
# Epoch 95/200
# 2103/2103 ━━━━━━━━━━━━━━━━━━━━ 15s 7ms/step - loss: 0.6611 - val_loss: 0.6713
# Epoch 96/200
# 2103/2103 ━━━━━━━━━━━━━━━━━━━━ 17s 8ms/step - loss: 0.6590 - val_loss: 0.6663
# Epoch 97/200
# 2103/2103 ━━━━━━━━━━━━━━━━━━━━ 17s 8ms/step - loss: 0.6655 - val_loss: 0.6641
# Epoch 98/200
# 2103/2103 ━━━━━━━━━━━━━━━━━━━━ 15s 7ms/step - loss: 0.6551 - val_loss: 0.6844
# Epoch 99/200
# 2103/2103 ━━━━━━━━━━━━━━━━━━━━ 17s 8ms/step - loss: 0.6597 - val_loss: 0.6622
# Epoch 100/200
# 2103/2103 ━━━━━━━━━━━━━━━━━━━━ 15s 7ms/step - loss: 0.6583 - val_loss: 0.6646
# Epoch 101/200
# 2103/2103 ━━━━━━━━━━━━━━━━━━━━ 16s 7ms/step - loss: 0.6580 - val_loss: 0.6647
# Epoch 102/200
# 2103/2103 ━━━━━━━━━━━━━━━━━━━━ 21s 10ms/step - loss: 0.6586 - val_loss: 0.6695
# Epoch 103/200
# 2103/2103 ━━━━━━━━━━━━━━━━━━━━ 20s 9ms/step - loss: 0.6607 - val_loss: 0.6641
# Epoch 104/200
# 2103/2103 ━━━━━━━━━━━━━━━━━━━━ 20s 9ms/step - loss: 0.6612 - val_loss: 0.6605
# Epoch 105/200
# 2103/2103 ━━━━━━━━━━━━━━━━━━━━ 18s 8ms/step - loss: 0.6650 - val_loss: 0.6613
# Epoch 106/200
# 2103/2103 ━━━━━━━━━━━━━━━━━━━━ 19s 8ms/step - loss: 0.6597 - val_loss: 0.6633
# Epoch 107/200
# 2103/2103 ━━━━━━━━━━━━━━━━━━━━ 17s 8ms/step - loss: 0.6588 - val_loss: 0.6641
# Epoch 108/200
# 2103/2103 ━━━━━━━━━━━━━━━━━━━━ 15s 7ms/step - loss: 0.6542 - val_loss: 0.6620
# Epoch 109/200
# 2103/2103 ━━━━━━━━━━━━━━━━━━━━ 19s 9ms/step - loss: 0.6534 - val_loss: 0.6617
# Epoch 110/200
# 2103/2103 ━━━━━━━━━━━━━━━━━━━━ 15s 7ms/step - loss: 0.6604 - val_loss: 0.6626
# Epoch 111/200
# 2103/2103 ━━━━━━━━━━━━━━━━━━━━ 20s 9ms/step - loss: 0.6539 - val_loss: 0.6789
# Epoch 112/200
# 2103/2103 ━━━━━━━━━━━━━━━━━━━━ 20s 9ms/step - loss: 0.6538 - val_loss: 0.6690
# Epoch 113/200
# 2103/2103 ━━━━━━━━━━━━━━━━━━━━ 20s 9ms/step - loss: 0.6576 - val_loss: 0.6655
# Epoch 114/200
# 2103/2103 ━━━━━━━━━━━━━━━━━━━━ 19s 9ms/step - loss: 0.6586 - val_loss: 0.6757
# Epoch 115/200
# 2103/2103 ━━━━━━━━━━━━━━━━━━━━ 18s 9ms/step - loss: 0.6605 - val_loss: 0.6622
# Epoch 116/200
# 2103/2103 ━━━━━━━━━━━━━━━━━━━━ 19s 9ms/step - loss: 0.6585 - val_loss: 0.6599
# Epoch 117/200
# 2103/2103 ━━━━━━━━━━━━━━━━━━━━ 15s 7ms/step - loss: 0.6561 - val_loss: 0.6617
# Epoch 118/200
# 2103/2103 ━━━━━━━━━━━━━━━━━━━━ 17s 8ms/step - loss: 0.6614 - val_loss: 0.7268
# Epoch 119/200
# 2103/2103 ━━━━━━━━━━━━━━━━━━━━ 18s 8ms/step - loss: 0.6614 - val_loss: 0.6910
# Epoch 120/200
# 2103/2103 ━━━━━━━━━━━━━━━━━━━━ 17s 7ms/step - loss: 0.6575 - val_loss: 0.6611
# Epoch 121/200
# 2103/2103 ━━━━━━━━━━━━━━━━━━━━ 15s 7ms/step - loss: 0.6541 - val_loss: 0.6597
# Epoch 122/200
# 2103/2103 ━━━━━━━━━━━━━━━━━━━━ 19s 9ms/step - loss: 0.6594 - val_loss: 0.6630
# Epoch 123/200
# 2103/2103 ━━━━━━━━━━━━━━━━━━━━ 18s 8ms/step - loss: 0.6593 - val_loss: 0.6707
# Epoch 124/200
# 2103/2103 ━━━━━━━━━━━━━━━━━━━━ 17s 8ms/step - loss: 0.6622 - val_loss: 0.6586
# Epoch 125/200
# 2103/2103 ━━━━━━━━━━━━━━━━━━━━ 18s 9ms/step - loss: 0.6602 - val_loss: 0.6609
# Epoch 126/200
# 2103/2103 ━━━━━━━━━━━━━━━━━━━━ 17s 8ms/step - loss: 0.6530 - val_loss: 0.6598
# Epoch 127/200
# 2103/2103 ━━━━━━━━━━━━━━━━━━━━ 19s 9ms/step - loss: 0.6592 - val_loss: 0.6603
# Epoch 128/200
# 2103/2103 ━━━━━━━━━━━━━━━━━━━━ 18s 9ms/step - loss: 0.6555 - val_loss: 0.6613
# Epoch 129/200
# 2103/2103 ━━━━━━━━━━━━━━━━━━━━ 20s 9ms/step - loss: 0.6584 - val_loss: 0.6719
# Epoch 130/200
# 2103/2103 ━━━━━━━━━━━━━━━━━━━━ 21s 10ms/step - loss: 0.6569 - val_loss: 0.6850
# Epoch 131/200
# 2103/2103 ━━━━━━━━━━━━━━━━━━━━ 18s 8ms/step - loss: 0.6507 - val_loss: 0.6595
# Epoch 132/200
# 2103/2103 ━━━━━━━━━━━━━━━━━━━━ 20s 9ms/step - loss: 0.6530 - val_loss: 0.6653
# Epoch 133/200
# 2103/2103 ━━━━━━━━━━━━━━━━━━━━ 20s 9ms/step - loss: 0.6526 - val_loss: 0.7072
# Epoch 134/200
# 2103/2103 ━━━━━━━━━━━━━━━━━━━━ 20s 9ms/step - loss: 0.6579 - val_loss: 0.6679
# Epoch 135/200
# 2103/2103 ━━━━━━━━━━━━━━━━━━━━ 17s 8ms/step - loss: 0.6534 - val_loss: 0.6638
# Epoch 136/200
# 2103/2103 ━━━━━━━━━━━━━━━━━━━━ 20s 9ms/step - loss: 0.6528 - val_loss: 0.6677
# Epoch 137/200
# 2103/2103 ━━━━━━━━━━━━━━━━━━━━ 18s 9ms/step - loss: 0.6565 - val_loss: 0.6847
# Epoch 138/200
# 2103/2103 ━━━━━━━━━━━━━━━━━━━━ 19s 9ms/step - loss: 0.6560 - val_loss: 0.6635
# Epoch 139/200
# 2103/2103 ━━━━━━━━━━━━━━━━━━━━ 20s 9ms/step - loss: 0.6515 - val_loss: 0.6645
# Epoch 140/200
# 2103/2103 ━━━━━━━━━━━━━━━━━━━━ 22s 10ms/step - loss: 0.6584 - val_loss: 0.6954
# Epoch 141/200
# 2103/2103 ━━━━━━━━━━━━━━━━━━━━ 16s 8ms/step - loss: 0.6571 - val_loss: 0.6922
# Epoch 142/200
# 2103/2103 ━━━━━━━━━━━━━━━━━━━━ 18s 8ms/step - loss: 0.6589 - val_loss: 0.6697
# Epoch 143/200
# 2103/2103 ━━━━━━━━━━━━━━━━━━━━ 18s 8ms/step - loss: 0.6533 - val_loss: 0.6596
# Epoch 144/200
# 2103/2103 ━━━━━━━━━━━━━━━━━━━━ 19s 9ms/step - loss: 0.6543 - val_loss: 0.6695
# Epoch 145/200
# 2103/2103 ━━━━━━━━━━━━━━━━━━━━ 15s 7ms/step - loss: 0.6538 - val_loss: 0.6588
# Epoch 146/200
# 2103/2103 ━━━━━━━━━━━━━━━━━━━━ 17s 8ms/step - loss: 0.6538 - val_loss: 0.6594
# Epoch 147/200
# 2103/2103 ━━━━━━━━━━━━━━━━━━━━ 17s 8ms/step - loss: 0.6523 - val_loss: 0.6741
# Epoch 148/200
# 2103/2103 ━━━━━━━━━━━━━━━━━━━━ 15s 7ms/step - loss: 0.6516 - val_loss: 0.6599
# Epoch 149/200
# 2103/2103 ━━━━━━━━━━━━━━━━━━━━ 18s 8ms/step - loss: 0.6600 - val_loss: 0.6643
# Epoch 150/200
# 2103/2103 ━━━━━━━━━━━━━━━━━━━━ 17s 8ms/step - loss: 0.6581 - val_loss: 0.6594
# Epoch 151/200
# 2103/2103 ━━━━━━━━━━━━━━━━━━━━ 18s 8ms/step - loss: 0.6616 - val_loss: 0.6669
# Epoch 152/200
# 2103/2103 ━━━━━━━━━━━━━━━━━━━━ 16s 8ms/step - loss: 0.6542 - val_loss: 0.6753
# Epoch 153/200
# 2103/2103 ━━━━━━━━━━━━━━━━━━━━ 18s 8ms/step - loss: 0.6569 - val_loss: 0.6608
# Epoch 154/200
# 2103/2103 ━━━━━━━━━━━━━━━━━━━━ 18s 8ms/step - loss: 0.6571 - val_loss: 0.6695
# Epoch 155/200
# 2103/2103 ━━━━━━━━━━━━━━━━━━━━ 17s 8ms/step - loss: 0.6494 - val_loss: 0.6921
# Epoch 156/200
# 2103/2103 ━━━━━━━━━━━━━━━━━━━━ 16s 7ms/step - loss: 0.6574 - val_loss: 0.6597
# Epoch 157/200
# 2103/2103 ━━━━━━━━━━━━━━━━━━━━ 16s 8ms/step - loss: 0.6539 - val_loss: 0.6597
# Epoch 158/200
# 2103/2103 ━━━━━━━━━━━━━━━━━━━━ 15s 7ms/step - loss: 0.6554 - val_loss: 0.6759
# Epoch 159/200
# 2103/2103 ━━━━━━━━━━━━━━━━━━━━ 16s 8ms/step - loss: 0.6545 - val_loss: 0.6597
# Epoch 160/200
# 2103/2103 ━━━━━━━━━━━━━━━━━━━━ 15s 7ms/step - loss: 0.6485 - val_loss: 0.6601
# Epoch 161/200
# 2103/2103 ━━━━━━━━━━━━━━━━━━━━ 18s 8ms/step - loss: 0.6552 - val_loss: 0.6601
# Epoch 162/200
# 2103/2103 ━━━━━━━━━━━━━━━━━━━━ 17s 8ms/step - loss: 0.6582 - val_loss: 0.6585
# Epoch 163/200
# 2103/2103 ━━━━━━━━━━━━━━━━━━━━ 20s 9ms/step - loss: 0.6547 - val_loss: 0.6591
# Epoch 164/200
# 2103/2103 ━━━━━━━━━━━━━━━━━━━━ 16s 8ms/step - loss: 0.6520 - val_loss: 0.6589
# Epoch 165/200
# 2103/2103 ━━━━━━━━━━━━━━━━━━━━ 19s 9ms/step - loss: 0.6533 - val_loss: 0.6596
# Epoch 166/200
# 2103/2103 ━━━━━━━━━━━━━━━━━━━━ 18s 8ms/step - loss: 0.6484 - val_loss: 0.6650
# Epoch 167/200
# 2103/2103 ━━━━━━━━━━━━━━━━━━━━ 20s 9ms/step - loss: 0.6551 - val_loss: 0.6596
# Epoch 168/200
# 2103/2103 ━━━━━━━━━━━━━━━━━━━━ 20s 9ms/step - loss: 0.6544 - val_loss: 0.6662
# Epoch 169/200
# 2103/2103 ━━━━━━━━━━━━━━━━━━━━ 18s 8ms/step - loss: 0.6559 - val_loss: 0.6610
# Epoch 170/200
# 2103/2103 ━━━━━━━━━━━━━━━━━━━━ 16s 8ms/step - loss: 0.6587 - val_loss: 0.6638
# Epoch 171/200
# 2103/2103 ━━━━━━━━━━━━━━━━━━━━ 17s 8ms/step - loss: 0.6526 - val_loss: 0.6648
# Epoch 172/200
# 2103/2103 ━━━━━━━━━━━━━━━━━━━━ 18s 8ms/step - loss: 0.6551 - val_loss: 0.6720
# Epoch 173/200
# 2103/2103 ━━━━━━━━━━━━━━━━━━━━ 18s 8ms/step - loss: 0.6515 - val_loss: 0.6670
# Epoch 174/200
# 2103/2103 ━━━━━━━━━━━━━━━━━━━━ 20s 9ms/step - loss: 0.6524 - val_loss: 0.6585
# Epoch 175/200
# 2103/2103 ━━━━━━━━━━━━━━━━━━━━ 20s 9ms/step - loss: 0.6542 - val_loss: 0.6601
# Epoch 176/200
# 2103/2103 ━━━━━━━━━━━━━━━━━━━━ 18s 8ms/step - loss: 0.6539 - val_loss: 0.6599
# Epoch 177/200
# 2103/2103 ━━━━━━━━━━━━━━━━━━━━ 20s 9ms/step - loss: 0.6545 - val_loss: 0.6646
# Epoch 178/200
# 2103/2103 ━━━━━━━━━━━━━━━━━━━━ 18s 8ms/step - loss: 0.6559 - val_loss: 0.6653
# Epoch 179/200
# 2103/2103 ━━━━━━━━━━━━━━━━━━━━ 18s 8ms/step - loss: 0.6556 - val_loss: 0.6951
# Epoch 180/200
# 2103/2103 ━━━━━━━━━━━━━━━━━━━━ 20s 9ms/step - loss: 0.6485 - val_loss: 0.6674
# Epoch 181/200
# 2103/2103 ━━━━━━━━━━━━━━━━━━━━ 18s 8ms/step - loss: 0.6529 - val_loss: 0.6594
# Epoch 182/200
# 2103/2103 ━━━━━━━━━━━━━━━━━━━━ 20s 9ms/step - loss: 0.6521 - val_loss: 0.6590
# Epoch 183/200
# 2103/2103 ━━━━━━━━━━━━━━━━━━━━ 18s 8ms/step - loss: 0.6542 - val_loss: 0.6580
# Epoch 184/200
# 2103/2103 ━━━━━━━━━━━━━━━━━━━━ 16s 8ms/step - loss: 0.6549 - val_loss: 0.6633
# Epoch 185/200
# 2103/2103 ━━━━━━━━━━━━━━━━━━━━ 17s 8ms/step - loss: 0.6501 - val_loss: 0.6574
# Epoch 186/200
# 2103/2103 ━━━━━━━━━━━━━━━━━━━━ 18s 8ms/step - loss: 0.6527 - val_loss: 0.6639
# Epoch 187/200
# 2103/2103 ━━━━━━━━━━━━━━━━━━━━ 18s 9ms/step - loss: 0.6534 - val_loss: 0.6630
# Epoch 188/200
# 2103/2103 ━━━━━━━━━━━━━━━━━━━━ 20s 9ms/step - loss: 0.6543 - val_loss: 0.6939
# Epoch 189/200
# 2103/2103 ━━━━━━━━━━━━━━━━━━━━ 20s 9ms/step - loss: 0.6463 - val_loss: 0.6579
# Epoch 190/200
# 2103/2103 ━━━━━━━━━━━━━━━━━━━━ 20s 9ms/step - loss: 0.6560 - val_loss: 0.6755
# Epoch 191/200
# 2103/2103 ━━━━━━━━━━━━━━━━━━━━ 19s 9ms/step - loss: 0.6479 - val_loss: 0.6607
# Epoch 192/200
# 2103/2103 ━━━━━━━━━━━━━━━━━━━━ 20s 9ms/step - loss: 0.6517 - val_loss: 0.6575
# Epoch 193/200
# 2103/2103 ━━━━━━━━━━━━━━━━━━━━ 20s 9ms/step - loss: 0.6486 - val_loss: 0.6604
# Epoch 194/200
# 2103/2103 ━━━━━━━━━━━━━━━━━━━━ 14s 6ms/step - loss: 0.6504 - val_loss: 0.6884
# Epoch 195/200
# 2103/2103 ━━━━━━━━━━━━━━━━━━━━ 13s 6ms/step - loss: 0.6539 - val_loss: 0.6590
# Epoch 196/200
# 2103/2103 ━━━━━━━━━━━━━━━━━━━━ 22s 10ms/step - loss: 0.6532 - val_loss: 0.6999
# Epoch 197/200
# 2103/2103 ━━━━━━━━━━━━━━━━━━━━ 20s 9ms/step - loss: 0.6540 - val_loss: 0.6635
# Epoch 198/200
# 2103/2103 ━━━━━━━━━━━━━━━━━━━━ 20s 9ms/step - loss: 0.6500 - val_loss: 0.6598
# Epoch 199/200
# 2103/2103 ━━━━━━━━━━━━━━━━━━━━ 17s 8ms/step - loss: 0.6457 - val_loss: 0.6599
# Epoch 200/200
# 2103/2103 ━━━━━━━━━━━━━━━━━━━━ 19s 9ms/step - loss: 0.6533 - val_loss: 0.6601
# Mapper LSTM weights saved to file.

# %% [markdown]
# **Prediction**

# %%
(
    x_train_seq,
    x_test_seq,
    y_train_seq,
    y_test_seq,
    z_train_seq,
    z_test_seq,
) = train_test_split(
    EIT_seq,
    perm_array_seq,
    latent_rep,
    test_size=0.1,
    shuffle=False,
    random_state=42,
)

# %%
def generate_perm_from_eit(voltage_measurements, lstm_mapper, vae_decoder):
    pred_latent = lstm_mapper.predict(voltage_measurements)
    perm_pred = vae_decoder.predict(pred_latent).reshape(-1, 2840)
    return perm_pred

# %%
predicted_permittivities = generate_perm_from_eit(x_test_seq, lstm_mapper, vae.decoder)
# Out:
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step

# %% [markdown]
# **Results**

# %%
random_indices, selected_true_perms, selected_predicted_perms = select_random_instances(
    x_test_seq, y_test_seq, predicted_permittivities, num_instances=10
)

# Plotting and saving mesh plots
mesh_plot_comparisons(
    mesh_obj,
    random_indices,
    selected_true_perms,
    selected_predicted_perms,
    save_dir="LSTM_Mapper_Mesh_Plots_Exp1",
    gif_name="LSTM_Mapper.gif",
    gif_title="LSTM Mapper Performance Exp",
)

# %% [markdown]
# **Error plot**

# %%
perm_error = calculate_perm_error(y_test_seq, predicted_permittivities)

# %%
plot_boxplot(
    data=perm_error,
    ylabel="Deviation in FEM elements",
    title="Box Plot for LSTM Mapper",
    savefig_name="LSTM_Mapper_Boxplot(snr_30).png",
    save_dir="LSTM_Mapper_Mesh_Plots_Exp1",
)

# %%
mean_deviation = np.mean(perm_error)
median_deviation = np.median(perm_error)
standard_deviation = np.std(perm_error)
max_dev = np.max(perm_error)
min_dev = np.min(perm_error)

print(
    f"Mean Deviation: {mean_deviation:.2f},\t\t-> {mean_deviation/mesh_obj.n_elems*100:.2f}%"
)
print(
    f"Median Deviation: {median_deviation:.2f},\t-> {median_deviation/mesh_obj.n_elems*100:.2f}%"
)
print(
    f"Standard Deviation: {standard_deviation:.2f},\t-> {standard_deviation/mesh_obj.n_elems*100:.2f}%"
)
print(f"Max Deviation: {max_dev:.2f},\t\t-> {max_dev/mesh_obj.n_elems*100:.2f}%")
print(f"Min Deviation: {min_dev:.2f},\t\t-> {min_dev/mesh_obj.n_elems*100:.2f}%")
# Out:
# Mean Deviation: 12.43,		-> 0.44%
# Median Deviation: 9.00,	-> 0.32%
# Standard Deviation: 25.24,	-> 0.89%
# Max Deviation: 128.00,		-> 4.51%
# Min Deviation: -79.00,		-> -2.78%

# %% [markdown]
# **Time sequence**

# %%
x_test_seq.shape, y_test_seq.shape, predicted_permittivities.shape
# Out:
# ((2078, 4, 32, 32, 1), (2078, 2840, 1), (2078, 2840))

# %%
def get_obj_FEMs(perm):
    obj_pms = np.where(perm > np.mean(perm))[0]
    return len(obj_pms)

# %%
rs_true = list()
rs_pred = list()

for i, ele in enumerate(predicted_permittivities):
    rs_true.append(get_obj_FEMs(ele))
    rs_pred.append(get_obj_FEMs(y_test_seq[i, :, 0]))

rs_true = np.array(rs_true)
rs_pred = np.array(rs_pred)

# %%
def scale_value(value, new_min=0.2, new_max=0.5):
    old_min, old_max = np.min(value), np.max(value)
    return new_min + (value - old_min) * (new_max - new_min) / (old_max - old_min)


rs_true = scale_value(rs_true)
rs_pred = scale_value(rs_pred)

# %%
plt.plot(rs_true[:600], label="True")
plt.plot(rs_pred[:600], label="Pred")
plt.legend()

# %%
Lplt = LinePlot()

# %%
Lplt.add_yvals(rs_true[:600], y_name="True")
Lplt.add_yvals(rs_pred[:600], y_name="Pred")
# Out:
# Added True with 600 entries.
# Current data stack:
#        True
# 0  0.497170
# 1  0.498302
# 2  0.494906
# 3  0.489811
# 4  0.486981
# Added Pred with 600 entries.
# Current data stack:
#        True      Pred
# 0  0.497170  0.489529
# 1  0.498302  0.492670
# 2  0.494906  0.494241
# 3  0.489811  0.493717
# 4  0.486981  0.489529

# %%
Lplt.export(f_name="line_results.csv")
# Out:
# **Export**
#
# Current data stack:
#        True      Pred  x
# 0  0.497170  0.489529  0
# 1  0.498302  0.492670  1
# 2  0.494906  0.494241  2
# 3  0.489811  0.493717  3
# 4  0.486981  0.489529  4
#
# ***********
# LaTeX code:
# ***********
#
# \begin{figure}[h]
#     \centering
#     \tikzstyle{every node}=[font=\footnotesize]
#     \begin{tikzpicture}
#         \begin{axis}[
#             ylabel={y-label},
#             xlabel={x-label},
#             % xtick={0,1,...,10},
#             width=7.5cm,
#             height=3cm,
#             at={(0cm,0cm)},
#             scale only axis,
#             axis background/.style={fill=white},
#             grid=both,
#             legend columns = 2,
#             legend style={at={(0,1.05)}, legend cell align=left, align=left, draw=white!15!black, mark options={draw=none}, anchor=south west},
#          ]
#         \addplot[]
#         	table[x=x,y=True,col sep=comma]{line_results.csv};
#         \addlegendentry{True};
#         \addplot[]
#         	table[x=x,y=Pred,col sep=comma]{line_results.csv};
#         \addlegendentry{Pred};
#         \end{axis}
#     \end{tikzpicture}
#     \caption{Caption of the plot.}
#     \label{fig:Caption of the plot.}
# \end{figure}
